# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\krish naik data science bootcamp\python\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\krish naik data science bootcamp\python\venv\lib\site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\krish naik data science bootcamp\python\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\krish naik data science bootcamp\python\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\krish naik data science bootcamp\python\venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\krish naik data science bootcamp\python\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# array,list, dict, tuple, set, matrix, vector

# %% [markdown]
# # Series in pandas
# - It is a one dimensional labelled array

# %%
import pandas as pd

# %%
s1 = pd.Series([10,20,30,40,50,60])
print(s1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
s2 = pd.Series([10,20,30,40,50,60], index = ['a', 'b', 'c', 'd', 'e', 'f'], name = "scores")  # Changing index to alphabets
print(s2)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# Name: scores, dtype: int64

# %%
# Create series from dict 

data = {'a': 10, 'b': 20, 'c': 30, 'd': 40}
s3 = pd.Series(data)
print(s3)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
import numpy as np

# %%
np_array = np.array([10, 20, 30, 40, 50, 60])
s4 = pd.Series(np_array)
print(s4)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
# Create series from dict 

data = {'a': 10, 'b' : "20", 'c': 1.11, 'd': True}
s6 = pd.Series(data)
print(s6)
# Out:
# a      10
# b      20
# c    1.11
# d    True
# dtype: object

# %%
data = {'a': 10, 'b' : "20", '1': 1.11, '2': True}
s5 = pd.Series(data)
print(s5)
# Out:
# a      10
# b      20
# 1    1.11
# 2    True
# dtype: object

# %%
# Create series from dict 

data = {'a': 10, 'b' : "20", 'c': 30, 'd': 40}
s7 = pd.Series(data , name = 'scores')
print(s7)
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: scores, dtype: object

# %%
# 2D, 3D --> [[1,2], [23,3], [45,56]] --> flatten --> np.flatten() --> []

# %%
print(s7.index)
print(s7.values)

# dict ---> keys and values

print(s7.dtypes)
print(s7.name)
print(s7.shape)
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')
# [10 '20' 30 40]
# object
# scores
# (4,)

# %% [markdown]
# # Series indexing and slicing

# %%
print(s7)
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: scores, dtype: object

# %%
print(s7.values[0])
# Out:
# 10

# %%
# Positional Indexing ---> It starts from Zero 
# Index --> 'a': 10, 'b':20, 'c': 30
# native index of value 10 is 0 i.e your positional indexing  access by s1.iloc["index"]
# s1.loc['a'] --> 10
# s1.iloc[0] --> 10
# s1[0] ---> deprecated (Not used in latets version, also devvelopers are not providing support) i.e loc native index

# %%
print(s7.loc['a']) # Indexing
# Out:
# 10

# %%
print(s7.iloc[0]) # Positional Indexing
# Out:
# 10

# %%
print(s7[0])
# Out:
# 10
# C:\Users\pnaik8\AppData\Local\Temp\ipykernel_21148\2729629825.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s7[0])

# %%
print(s7.loc[['a','b']]) # Indexing
# Out:
# a    10
# b    20
# Name: scores, dtype: object

# %%
print(s7.iloc[0:2])  # Positional indexing (exclusive)
# Out:
# a    10
# b    20
# Name: scores, dtype: object

# %%
data = {'a': 10, 'b' : 20, 'c': 30, 'd': 40, 0 : 100, 1: 101, 2: 400, 6:700}
s9 = pd.Series(data , name = 'scores')
print(s9)
# Out:
# a     10
# b     20
# c     30
# d     40
# 0    100
# 1    101
# 2    400
# 6    700
# Name: scores, dtype: int64

# %%
s9.loc[0:2]    # Inclusive - The index has to be present
# Out:
# 0    100
# 1    101
# 2    400
# Name: scores, dtype: int64

# %%
# Slicing 
# - loc[start, end ] : end is inclusive 
# - iloc [start, end ] : end is exclusive

# %% [markdown]
# # dataframe

# %%
data = {
    'Name' : ['Ananth', 'Pushpak', 'Nikhil'],
    'Age'  : [24, 26, 28],
    'City' : ['Bengaluru', 'Hyderabad', 'Delhi'
              ]}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age       City
# 0   Ananth   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# 2   Nikhil   28      Delhi

# %%
data_1 = [
    {'Name' : 'Anath', 'Age': '24', 'City': 'Bengaluru'},
    {'Name' : 'Pushpak', 'Age': '26', 'City': 'Hyderabad'},
    {'Name' : 'Nikhil', 'Age': '28', 'City': 'Delhi'}


]

# %%
df_1 = pd.DataFrame(data_1)
print(df_1)
# Out:
#       Name Age       City
# 0    Anath  24  Bengaluru
# 1  Pushpak  26  Hyderabad
# 2   Nikhil  28      Delhi

# %%
arr_data = np.array([[1,2],[3,4],[5,6]])

# %%
df_2 = pd.DataFrame(arr_data)
print(df_2)
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6

# %%
df_2 = pd.DataFrame(arr_data, columns = ['A', 'B'])
print(df_2)
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 2  5  6

# %% [markdown]
# # Accessing the Values

# %%
data = {
    'Name' : ['Ananth', 'Pushpak', 'Nikhil'],
    'Age'  : [24, 26, 28],
    'City' : ['Bengaluru', 'Hyderabad', 'Delhi'
              ]}

df_4 = pd.DataFrame(data)

# %%
print(df_4)
# Out:
#       Name  Age       City
# 0   Ananth   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# 2   Nikhil   28      Delhi

# %%
type(df_4['Name'])
# Out:
# pandas.core.series.Series

# %%
print(df_4['Name'])
print("="*40)
print(df_4[['Name', 'Age']])
print("="* 40)
print(df.loc[0])
print("="*40)
print(df.loc[0:1]) # inclusive i.e Inclusive of index 1 
print("="*40)
print(df.iloc[0])
print("="*40)
print(df.iloc[0:1]) # Exclusive i.e Exclusive of index 1
# Out:
# 0     Ananth
# 1    Pushpak
# 2     Nikhil
# Name: Name, dtype: object
# ========================================
#       Name  Age
# 0   Ananth   24
# 1  Pushpak   26
# 2   Nikhil   28
# ========================================
# Name       Ananth
# Age            24
# City    Bengaluru
# Name: 0, dtype: object
# ========================================
#       Name  Age       City
# 0   Ananth   24  Bengaluru
# 1  Pushpak   26  Hyderabad
# ========================================
# Name       Ananth
# Age            24
# City    Bengaluru
# Name: 0, dtype: object
# ========================================
#      Name  Age       City
# 0  Ananth   24  Bengaluru

# %% [markdown]
# # Data
# #### .csv ---> Comma Seperated Values
# ##### Name, Age
# ##### Monal, 30
# ##### Kevin, 26
#
#
# #### .dict--> {'Name': ["Monal", "Kevin],
# ####               'Age':[30,26],
# ####                }
#
#
# #### Jason - Java Script opject notation
# #### .jason --> [
#     {'name' : 'Monal',
#     'age' :30
#     },
#     {'name': 'Kevin',
#     'age': 26}
#     }
# ]

# %% [markdown]
# # Working with real Dataset

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

# %%
df = pd.read_csv(titanic_dataset_github_url) # Raw Data

# %%
# Preview of the data Frame 

df.head()      # First 5 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()   # last 5 rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(df.tail())     # This is for terminal preview
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.loc[0] # First row
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.loc[0, 'Name']   # Name of the passenger at index 0
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df.loc[0:4]   # In loc the last value is inclusive
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0]  # 1st row
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.iloc[0:4]  # 4th value is exclusive
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.iloc[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[0,3]    # iloc only has positional index
# Out:
# 'Braund, Mr. Owen Harris'

# %% [markdown]
# # Conditional Selection

# %%
# Get all the rows where person age is greater than 70 

# df[condition]

df[df['Age'] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
df[df['Age'] < 20]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                  Rice, Master. Eugene
# ..           ...       ...     ...                                   ...
# 855          856         1       3            Aks, Mrs. Sam (Leah Rosen)
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 7      male   2.0      3      1   349909  21.0750   NaN        S
# 9    female  14.0      1      0   237736  30.0708   NaN        C
# 10   female   4.0      1      1  PP 9549  16.7000    G6        S
# 14   female  14.0      0      0   350406   7.8542   NaN        S
# 16     male   2.0      4      1   382652  29.1250   NaN        Q
# ..      ...   ...    ...    ...      ...      ...   ...      ...
# 855  female  18.0      0      1   392091   9.3500   NaN        S
# 869    male   4.0      1      1   347742  11.1333   NaN        S
# 875  female  15.0      0      0     2667   7.2250   NaN        C
# 877    male  19.0      0      0   349212   7.8958   NaN        S
# 887  female  19.0      0      0   112053  30.0000   B42        S
#
# [164 rows x 12 columns]

# %%
# Save data using a varibale so we can use it later
older_passengers = df[df['Age'] > 70]
older_passengers.head()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S

# %%
# Get all the females who survived 

df[(df['Sex'] == 'female') & df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [233 rows x 12 columns]

# %%
# Only name and age of all the females who survived 

female_surviors_subset = df[(df['Sex'] == 'female') & df['Survived'] == 1][['Name', 'Age']]
female_surviors_subset.head(10)
# Out:
#                                                  Name   Age
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                              Heikkinen, Miss. Laina  26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0
# 11                           Bonnell, Miss. Elizabeth  58.0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   55.0
# 19                            Masselmani, Mrs. Fatima   NaN
# 22                        McGowan, Miss. Anna "Annie"  15.0

# %%
# Total Number of survivals 

survived = len(df[df['Survived'] == 1])
notsurvived = len(df[df['Survived']== 0])
print(notsurvived + survived)
# Out:
# 891

# %%
survived/(notsurvived + survived)
# Out:
# 0.3838383838383838

# %%
notsurvived/(notsurvived + survived)
# Out:
# 0.6161616161616161

# %%
# Females who survived with name and age 

female_surviors_subset_loc = df.loc[(df['Sex'] == 'female') & df['Survived'] == 1][['Name', 'Age']]
female_surviors_subset_loc.head()
# Out:
#                                                 Name   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0

# %%
df.loc[0, ['Cabin']]    # df.loc uses square brackets , Square bracekt [] is used in list, array and dataFrame
# Out:
# Cabin    NaN
# Name: 0, dtype: object

# %% [markdown]
# # Slicing Rows and Columns

# %%
df.loc[0:4, ['Name', 'Age']]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# I want first 3 rows and first 2 columns only using numbers and index 

df.iloc[0:3, 0:2]
# Out:
#    PassengerId  Survived
# 0            1         0
# 1            2         1
# 2            3         1

# %%
# First 3 rows and selected columns by index, I want only columns 1 and 3

df.iloc[0:3,[1,3] ]
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1                             Heikkinen, Miss. Laina

# %%
# I want name as first column and surved as second column 

df.iloc[0:3, [3,1]]
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1

# %%
df.loc[0:3, ['Name', 'Survived']]
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1

# %%
df.loc[0:3, ['Survived', 'Name']]
# Out:
#    Survived                                               Name
# 0         0                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1                             Heikkinen, Miss. Laina
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Adding age + 1 by creating a subset 


subset = df[df['Sex'] == 'male']
subset['Age'] = subset['Age'] + 1

print(subset)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    23.0      1      0         A/5 21171   7.2500   NaN        S
# 4    36.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    55.0      0      0             17463  51.8625   E46        S
# 7     3.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  29.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  26.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  28.0      0      0            211536  13.0000   NaN        S
# 889  27.0      0      0            111369  30.0000  C148        C
# 890  33.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]
# C:\Users\pnaik8\AppData\Local\Temp\ipykernel_21148\1614144536.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['Age'] = subset['Age'] + 1

# %%
subset = df[df['Sex'] == 'male'].copy()  # Copy and then change the value . Here copy will create a new reference, Copy will not change your original data 
subset['Age'] += 1
print(subset)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    23.0      1      0         A/5 21171   7.2500   NaN        S
# 4    36.0      0      0            373450   8.0500   NaN        S
# 5     NaN      0      0            330877   8.4583   NaN        Q
# 6    55.0      0      0             17463  51.8625   E46        S
# 7     3.0      3      1            349909  21.0750   NaN        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  29.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884  26.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 886  28.0      0      0            211536  13.0000   NaN        S
# 889  27.0      0      0            111369  30.0000  C148        C
# 890  33.0      0      0            370376   7.7500   NaN        Q
#
# [577 rows x 12 columns]

# %%
print(subset.head(2))
print(df.head(2))
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 0            1         0       3   Braund, Mr. Owen Harris  male  23.0      1
# 4            5         0       3  Allen, Mr. William Henry  male  36.0      0
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S
# 4      0     373450  8.05   NaN        S
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# iloc ---> copy
# loc ---> may be view 
# df[...] --> may be view

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_by_name = df.set_index('Name')
df_by_name.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S

# %%
print(df_by_name.loc["Allen, Mr. William Henry"])
# Out:
# PassengerId         5
# Survived            0
# Pclass              3
# Sex              male
# Age              35.0
# SibSp               0
# Parch               0
# Ticket         373450
# Fare             8.05
# Cabin             NaN
# Embarked            S
# Name: Allen, Mr. William Henry, dtype: object

# %%
df_by_name.reset_index()
df_by_name.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# Name
# Braund, Mr. Owen Harris                                 1      0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...      1      0
# Heikkinen, Miss. Laina                                  0      0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            1      0
# Allen, Mr. William Henry                                0      0
#
#                                                               Ticket     Fare  \
# Name
# Braund, Mr. Owen Harris                                    A/5 21171   7.2500
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          PC 17599  71.2833
# Heikkinen, Miss. Laina                              STON/O2. 3101282   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  113803  53.1000
# Allen, Mr. William Henry                                      373450   8.0500
#
#                                                    Cabin Embarked
# Name
# Braund, Mr. Owen Harris                              NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...   C85        C
# Heikkinen, Miss. Laina                               NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        C123        S
# Allen, Mr. William Henry                             NaN        S

# %%
df_by_name.reset_index(inplace = True)
df_by_name.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Reindex

# %%
sales_jan = pd.DataFrame({
    'Sales': [250, 400, 300]
}, index = ['Store_A', 'Store_B', 'Store_C'])

sales_jan
# Out:
#          Sales
# Store_A    250
# Store_B    400
# Store_C    300

# %%
sales_feb = pd.DataFrame({
    'Sales': [260,310]
}, index = ['Store_A','Store_C'])

sales_feb
# Out:
#          Sales
# Store_A    260
# Store_C    310

# %%
common_index = sales_jan.index

# %%
sales_feb_aligned = sales_feb.reindex(common_index)

# %%
sales_feb_aligned
# Out:
#          Sales
# Store_A  260.0
# Store_B    NaN
# Store_C  310.0

# %%
sales_diff = sales_feb_aligned['Sales'] - sales_jan['Sales']

sales_diff
# Out:
# Store_A    10.0
# Store_B     NaN
# Store_C    10.0
# Name: Sales, dtype: float64

# %%
sales_feb_aligned = sales_feb.reindex(common_index, fill_value = 0)

sales_feb_aligned
# Out:
#          Sales
# Store_A    260
# Store_B      0
# Store_C    310

# %%
sales_diff = sales_feb_aligned['Sales'] - sales_jan['Sales']

sales_diff
# Out:
# Store_A     10
# Store_B   -400
# Store_C     10
# Name: Sales, dtype: int64

# %%
sales_feb_new = pd.DataFrame({
    'Sales': [260,310, 100]
}, index = ['Store_A','Store_C', 'Store_D'])

sales_feb_new
# Out:
#          Sales
# Store_A    260
# Store_C    310
# Store_D    100

# %%
common_index = list(set(list(sales_jan.index)+ list(sales_feb.index)))

# %%
common_index
# Out:
# ['Store_B', 'Store_D', 'Store_A', 'Store_C']

# %%
sales_jan_aligned = sales_jan.reindex(common_index, fill_value = 0)
sales_jan_aligned
# Out:
#          Sales
# Store_B    400
# Store_D      0
# Store_A    250
# Store_C    300

# %%
sales_feb_new_aligned = sales_feb_new.reindex(common_index, fill_value = 0)
sales_feb_new_aligned
# Out:
#          Sales
# Store_B      0
# Store_D    100
# Store_A    260
# Store_C    310

# %%
to_check = 'Store_C'
print(sales_feb_aligned.loc[to_check])
print(sales_jan_aligned.loc[to_check])
# Out:
# Sales    310
# Name: Store_C, dtype: int64
# Sales    300
# Name: Store_C, dtype: int64

# %% [markdown]
# # For Columns

# %%
source_a = pd.DataFrame({
     'Product': ['Laptop', 'Tablet', 'Phone'],
     'Price': [1000, 500, 800],
     'Stock': [30, 50, 100]
})

source_a
# Out:
#   Product  Price  Stock
# 0  Laptop   1000     30
# 1  Tablet    500     50
# 2   Phone    800    100

# %%
source_b = pd.DataFrame({
    'Price': [980, 520, 810],
    'Product': ['Laptop', 'Tablet', 'Phone']
})

source_b
# Out:
#    Price Product
# 0    980  Laptop
# 1    520  Tablet
# 2    810   Phone

# %%
aligned_b = source_b.reindex(columns = source_a.columns, fill_value = 0)

aligned_b
# Out:
#   Product  Price  Stock
# 0  Laptop    980      0
# 1  Tablet    520      0
# 2   Phone    810      0

# %% [markdown]
# # Iteration in Pandas

# %%
df = pd.DataFrame({
    'Name' : ['heartline', 'gagan', 'gavin'],
    'Age' : [25,30,23],
    'City' : ['Delhi', 'Mumbai', 'Chennai']
})

# %%
for index, row in df.iterrows():
    print(f"{index}: {row['Name']} lives in {row['City']} and is {row['Age']} years old.")
# Out:
# 0: heartline lives in Delhi and is 25 years old.
# 1: gagan lives in Mumbai and is 30 years old.
# 2: gavin lives in Chennai and is 23 years old.

# %%
for row in df.itertuples():
    print(f"{row.Name} lives in {row.City}, and is {row.Age} years old.", end='\\n\\n')
# Out:
# heartline lives in Delhi, and is 25 years old.\n\ngagan lives in Mumbai, and is 30 years old.\n\ngavin lives in Chennai, and is 23 years old.\n\n

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
for i in df.index:
    print(i)
# Out:
# 0
# 1
# 2

# %%
for col in df.columns:
    print(f"Column:{col}")
    print(df[col].values, end = '\n\n')
# Out:
# Column:Name
# ['heartline' 'gagan' 'gavin']
#
# Column:Age
# [25 30 23]
#
# Column:City
# ['Delhi' 'Mumbai' 'Chennai']

# %% [markdown]
# # Condition based column creation using custom logic

# %%
df.head()
# Out:
#         Name  Age     City
# 0  heartline   25    Delhi
# 1      gagan   30   Mumbai
# 2      gavin   23  Chennai

# %%
# if >= 30, senior else young

# %%
values = []
for idx, row in df.iterrows():
    if row['Age'] < 30:
        values.append('young')
    else:
        values.append('Senior')

df['Category'] = values

# %%
df
# Out:
#         Name  Age     City Category
# 0  heartline   25    Delhi    young
# 1      gagan   30   Mumbai   Senior
# 2      gavin   23  Chennai    young

# %%
# vectorized using apply

# %%
df = pd.DataFrame({
    'Name' : ['heartline', 'gagan', 'gavin'],
    'Age' : [25,30,23],
    'City' : ['Delhi', 'Mumbai', 'Chennai']
})

# %%
df['Categories'] = df['Age'].apply(lambda age: 'young' if age < 30 else 'senior')

# %%
df
# Out:
#         Name  Age     City Categories
# 0  heartline   25    Delhi      young
# 1      gagan   30   Mumbai     senior
# 2      gavin   23  Chennai      young

# %%
# iterrows < itertuples < apply

# %% [markdown]
# # SORT
#
# 1. sort_values --- > data Values
# 2. sort_index --> rows/columns

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = pd.read_csv(titanic_dataset_github_url)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Sorted by Age 

sorted_df = df.sort_values(by = 'Age')
sorted_df[['Name', 'Age']].head(5)
# Out:
#                                 Name   Age
# 803  Thomas, Master. Assad Alexander  0.42
# 755        Hamalainen, Master. Viljo  0.67
# 644           Baclini, Miss. Eugenie  0.75
# 469    Baclini, Miss. Helene Barbara  0.75
# 78     Caldwell, Master. Alden Gates  0.83

# %%
sorted_df[['Name', 'Age']].tail(5)
# Out:
#                                          Name  Age
# 859                          Razi, Mr. Raihed  NaN
# 863         Sage, Miss. Dorothy Edith "Dolly"  NaN
# 868               van Melkebeke, Mr. Philemon  NaN
# 878                        Laleff, Mr. Kristo  NaN
# 888  Johnston, Miss. Catherine Helen "Carrie"  NaN

# %%
sorted_df.loc[0:100, ['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 289                               Connolly, Miss. Kate  22.0
# 323  Caldwell, Mrs. Albert Francis (Sylvia Mae Harb...  22.0
# 243                      Maenpaa, Mr. Matti Alexanteri  22.0
# 521                                    Vovk, Mr. Janko  22.0
# ..                                                 ...   ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  28.0
# 399                   Trout, Mrs. William H (Jessie L)  28.0
# 392                       Gustafsson, Mr. Johan Birger  28.0
# 635                                  Davis, Miss. Mary  28.0
# 100                            Petranec, Miss. Matilda  28.0
#
# [146 rows x 2 columns]

# %%
print(df['Age'].dtype)
# Out:
# float64

# %%
sorted_df = df.sort_values(by = 'Age')
print(sorted_df[['Name', "Age"]].tail(20))
# Out:
#                                              Name  Age
# 776                              Tobin, Mr. Roger  NaN
# 778                       Kilgannon, Mr. Thomas J  NaN
# 783                        Johnston, Mr. Andrew G  NaN
# 790                      Keane, Mr. Andrew "Andy"  NaN
# 792                       Sage, Miss. Stella Anna  NaN
# 793                      Hoyt, Mr. William Fisher  NaN
# 815                              Fry, Mr. Richard  NaN
# 825                               Flynn, Mr. John  NaN
# 826                                  Lam, Mr. Len  NaN
# 828                  McCormack, Mr. Thomas Joseph  NaN
# 832                                Saad, Mr. Amin  NaN
# 837                           Sirota, Mr. Maurice  NaN
# 839                          Marechal, Mr. Pierre  NaN
# 846                      Sage, Mr. Douglas Bullen  NaN
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  NaN
# 859                              Razi, Mr. Raihed  NaN
# 863             Sage, Miss. Dorothy Edith "Dolly"  NaN
# 868                   van Melkebeke, Mr. Philemon  NaN
# 878                            Laleff, Mr. Kristo  NaN
# 888      Johnston, Miss. Catherine Helen "Carrie"  NaN

# %%
# Sort by multiple columns 

df_sorted = df.sort_values(by = ['Pclass', 'Fare'])   # Ascending order

# %%
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 263          264         0       1            Harrison, Mr. William  male
# 633          634         0       1    Parr, Mr. William Henry Marsh  male
# 806          807         0       1           Andrews, Mr. Thomas Jr  male
# 815          816         0       1                 Fry, Mr. Richard  male
# 822          823         0       1  Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 263  40.0      0      0  112059   0.0   B94        S
# 633   NaN      0      0  112052   0.0   NaN        S
# 806  39.0      0      0  112050   0.0   A36        S
# 815   NaN      0      0  112058   0.0  B102        S
# 822  38.0      0      0   19972   0.0   NaN        S

# %%
df_sorted = df.sort_values(by = ['Pclass', 'Fare'], ascending = [True,False]) # ascending order

# %%
df_sorted.head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 27            28         0       1      Fortune, Mr. Charles Alexander
# 88            89         1       1          Fortune, Miss. Mabel Helen
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S

# %%
# Sort Index 

df_sorted.to_csv("a.csv")

# %%
# Sort index

# %%
# axis = 0 # rows
# axis = 1 # Columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_sort_2 = df.set_index('PassengerId')

# %%
df_sorted_by_index = df_sort_2.sort_index(axis = 0)

# %%
df_sorted_by_index.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df_sorted_by_index_c = df_sort_2.sort_index(axis = 0, ascending = False)
df_sorted_by_index.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# df_sorted_by_index_c = df_sort_2.sort_index(axis = 0, ascending = False, inplace = True )

# %% [markdown]
# # Sorting Columns alphapetically

# %%
df_sorted_cols = df.sort_index(axis = 1)

# %%
df_sorted_cols.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1         0         A/5 21171
# 1       1  female      1         1          PC 17599
# 2       3  female      0         1  STON/O2. 3101282
# 3       1  female      1         1            113803
# 4       3    male      0         0            373450

# %% [markdown]
# # Changing column order in Pandas

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = pd.read_csv(titanic_dataset_github_url)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
new_order = ['Name', 'Sex', 'Age', 'Pclass', 'Fare', 'Survived']

# %%
df_reordered = df[new_order]
print(df_reordered.head())
# Out:
#                                                 Name     Sex   Age  Pclass  \
# 0                            Braund, Mr. Owen Harris    male  22.0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                             Heikkinen, Miss. Laina  female  26.0       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                           Allen, Mr. William Henry    male  35.0       3
#
#       Fare  Survived
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         1
# 3  53.1000         1
# 4   8.0500         0

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sorted(df.columns)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'Ticket']

# %%
df.df_reordered = df[sorted(df.columns)]

df_reordered.head()
# Out:
# C:\Users\pnaik8\AppData\Local\Temp\ipykernel_21148\4020761821.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.df_reordered = df[sorted(df.columns)]
#                                                 Name     Sex   Age  Pclass  \
# 0                            Braund, Mr. Owen Harris    male  22.0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                             Heikkinen, Miss. Laina  female  26.0       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                           Allen, Mr. William Henry    male  35.0       3
#
#       Fare  Survived
# 0   7.2500         0
# 1  71.2833         1
# 2   7.9250         1
# 3  53.1000         1
# 4   8.0500         0

# %% [markdown]
# # Working with text data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df[['Name', 'Sex', 'Cabin']].head(10))
# Out:
#                                                 Name     Sex Cabin
# 0                            Braund, Mr. Owen Harris    male   NaN
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                             Heikkinen, Miss. Laina  female   NaN
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  C123
# 4                           Allen, Mr. William Henry    male   NaN
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male   E46
# 7                     Palsson, Master. Gosta Leonard    male   NaN
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   NaN
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   NaN

# %%
df['Name'].str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.len()   # Length of all the names
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
# Replace MR with Sir 

df['Name'].str.replace("Mr.", "Sir", regex = False)
# Out:
# 0                                Braund, Sir Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Sir William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Sir Karl Howell
# 890                                  Dooley, Sir Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.replace(r"\(.*\)", "", regex=True) # Removes anything inside the parentheses + parentheses
# Out:
# 0                       Braund, Mr. Owen Harris
# 1                   Cumings, Mrs. John Bradley
# 2                        Heikkinen, Miss. Laina
# 3                 Futrelle, Mrs. Jacques Heath
# 4                      Allen, Mr. William Henry
#                          ...
# 886                       Montvila, Rev. Juozas
# 887                Graham, Miss. Margaret Edith
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 889                       Behr, Mr. Karl Howell
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(",", expand=True)[0] #returns a DataFrame with each split part as a column
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: 0, Length: 891, dtype: object

# %%
df['Name'].str.find("Mr")
# Out:
# 0       8
# 1       9
# 2      -1
# 3      10
# 4       7
#        ..
# 886    -1
# 887    -1
# 888    -1
# 889     6
# 890     8
# Name: Name, Length: 891, dtype: int64

# %%
count = df['Name'].str.contains("Miss").sum()

# %%
print(count)
# Out:
# 182

# %%
import pandas as pd
import numpy as np

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"
   
iris_dataset_github_url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/refs/heads/master/iris.csv"
    
kaggle_link = "https://www.kaggle.com/datasets/yasserh/titanic-dataset/data"

# %%
df = pd.read_csv(titanic_dataset_github_url)

# %% [markdown]
# # Find Position of Substring

# %%
df['Name'].str.find("Mr")
# Out:
# 0       8
# 1       9
# 2      -1
# 3      10
# 4       7
#        ..
# 886    -1
# 887    -1
# 888    -1
# 889     6
# 890     8
# Name: Name, Length: 891, dtype: int64

# %%
# Count Passengers with "Miss" in name

count = df['Name'].str.contains("Miss").sum()
print("Number of 'Miss' : ", count)
# Out:
# Number of 'Miss' :  182

# %%
data = {
    "Name" : [
        'Monal K', 'Bhuvika', 'Niranjan', 'riyan'
    ],
    'Email': ['m@gmail.com', 'b@gmail.com', 'c@gmail.com', 'd@gmail.com'
              ]
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#        Name        Email
# 0   Monal K  m@gmail.com
# 1   Bhuvika  b@gmail.com
# 2  Niranjan  c@gmail.com
# 3     riyan  d@gmail.com

# %%
# Replace K with something else

df['Name'].str.replace("K", "Kumar", regex = False)
# Out:
# 0    Monal Kumar
# 1        Bhuvika
# 2       Niranjan
# 3          riyan
# Name: Name, dtype: object

# %%
df['Name'].str.pad(width = 20, side = 'left', fillchar = '-')
# Out:
# 0    -------------Monal K
# 1    -------------Bhuvika
# 2    ------------Niranjan
# 3    ---------------riyan
# Name: Name, dtype: object

# %% [markdown]
# # Options and Customizations

# %%
titanic_dataset_github_url = "https://raw.githubusercontent.com/datasciencedojo/datasets/refs/heads/master/titanic.csv"

df = titanic_dataset_github_url

# %%
df = pd.read_csv(titanic_dataset_github_url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# You cant see all columns and rows here 

pd.set_option('display.max_rows', 5)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# ..           ...       ...     ...
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 0        0  A/5 21171   7.2500   NaN        S
# 1        0   PC 17599  71.2833   C85        C
# ..     ...        ...      ...   ...      ...
# 889      0     111369  30.0000  C148        C
# 890      0     370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Show all columns (None())
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# ..           ...       ...     ...
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 0        0  A/5 21171   7.2500   NaN        S
# 1        0   PC 17599  71.2833   C85        C
# ..     ...        ...      ...   ...      ...
# 889      0     111369  30.0000  C148        C
# 890      0     370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_columns', 3)
df
# Out:
#      PassengerId  ...  Embarked
# 0              1  ...         S
# 1              2  ...         C
# ..           ...  ...       ...
# 889          890  ...         C
# 890          891  ...         Q
#
# [891 rows x 12 columns]

# %%
pd.set_option('display.max_columns', 30)

# %%
df[['Fare', 'Age']].head()
# Out:
#       Fare   Age
# 0   7.2500  22.0
# 1  71.2833  38.0
# 2   7.9250  26.0
# 3  53.1000  35.0
# 4   8.0500  35.0

# %%
# Set Float Precision to 2 Decimal Places. How to display we are not changing anything

pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df[['Fare', 'Age']].head()
# Out:
#    Fare   Age
# 0  7.25 22.00
# 1 71.28 38.00
# 2  7.92 26.00
# 3 53.10 35.00
# 4  8.05 35.00

# %%
# Check current value of an Option 

pd.get_option('display.max_rows')
# Out:
# 5

# %%
# Temporaily set option (context Manager)
with pd.option_context('display.max_rows', 3):       # Max rows only for viewing it wont change anything
    print(df)
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 0              1         0       3  Braund, Mr. Owen Harris  male 22.00
# ..           ...       ...     ...                      ...   ...   ...
# 890          891         0       3      Dooley, Mr. Patrick  male 32.00
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 0        1      0  A/5 21171  7.25   NaN        S
# ..     ...    ...        ...   ...   ...      ...
# 890      0      0     370376  7.75   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Resetting to Default 

pd.reset_option('display.max_rows')

# %%
pd.get_option('display.max_rows')
# Out:
# 60

# %%
# You can reset all options

pd.reset_option('all')
# Out:
# C:\Users\pnaik8\AppData\Local\Temp\ipykernel_7316\3192342.py:3: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# C:\Users\pnaik8\AppData\Local\Temp\ipykernel_7316\3192342.py:3: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[53], line 3
#       1 # You can reset all options
# ----> 3 pd.reset_option('all')
#
# File c:\Krish Naik Data Science Bootcamp\Python\venv\Lib\site-packages\pandas\_config\config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File c:\Krish Naik Data Science Bootcamp\Python\venv\Lib\site-packages\pandas\_config\config.py:212, in _reset_option(pat, silent)
#     205     raise ValueError(
#     206         "You must specify at least 4 characters when "
#     207         "resetting multiple keys, use the special keyword "
#     208         '"all" to reset all the options to their default value'
#     209     )
#     211 for k in keys:
# --> 212     _set_option(k, _registered_options[k].defval, silent=silent)
#
# File c:\Krish Naik Data Science Bootcamp\Python\venv\Lib\site-packages\pandas\_config\config.py:182, in _set_option(*args, **kwargs)
#     180         o.cb(key)
#     181 else:
# --> 182     o.cb(key)
#
# File c:\Krish Naik Data Science Bootcamp\Python\venv\Lib\site-packages\pandas\core\config_init.py:706, in register_converter_cb(key)
#     700 from pandas.plotting import (
#     701     deregister_matplotlib_converters,
#     702     register_matplotlib_converters,
#     703 )
#     705 if cf.get_option(key):
# --> 706     register_matplotlib_converters()
#     707 else:
#     708     deregister_matplotlib_converters()
#
# File c:\Krish Naik Data Science Bootcamp\Python\venv\Lib\site-packages\pandas\plotting\_misc.py:108, in register()
#      67 def register() -> None:
#      68     """
#      69     Register pandas formatters and converters with matplotlib.
#      70
#    (...)    106     TypeError: float() argument must be a string or a real number, not 'Period'
#     107     """
# --> 108     plot_backend = _get_plot_backend("matplotlib")
#     109     plot_backend.register()
#
# File c:\Krish Naik Data Science Bootcamp\Python\venv\Lib\site-packages\pandas\plotting\_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File c:\Krish Naik Data Science Bootcamp\Python\venv\Lib\site-packages\pandas\plotting\_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
import warnings

with warnings.catch_warnings():
    warnings.simplefilter('ignore', FutureWarning)
    pd.reset_option('all')

# %% [markdown]
# # Categorical data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Sex_C
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# 4      0            373450   8.0500   NaN        S    male

# %%
print(df['Sex'].dtype)    # Data type is a string for this object
# Out:
# object

# %%
# Convert a coumn to categorical 
df['sex_c'] = df['Sex'].astype('category')       # Data type is a Categorical i.e Male and Female are two sepeate groups
df[['Sex', 'sex_c']].head()
# Out:
#       Sex   sex_c
# 0    male    male
# 1  female  female
# 2  female  female
# 3  female  female
# 4    male    male

# %%
print(df['Sex'].dtype)
print(df['Sex_c'].dtype)
# Out:
# object
# category

# %%
df['Sex_c_categorical_codes'] = df['Sex_c'].cat.codes     # Converting categories into individual codes  Here Sex_c is categorical column

# %%
df[['Sex','Sex_c', 'Sex_c_categorical_codes']].head()
# Out:
#       Sex   Sex_c  Sex_c_categorical_codes
# 0    male    male                        1
# 1  female  female                        0
# 2  female  female                        0
# 3  female  female                        0
# 4    male    male                        1

# %%
# Machine learning cannot understand strings it only understands 0 and 1

# %%
df['Sex_apply_category'] = df['Sex'].apply(lambda x : 0 if x == 'male' else 1 ) # Python method for doing it

# %%
df[['Sex','Sex_c', 'Sex_c_categorical_codes']].head()
# Out:
#       Sex   Sex_c  Sex_c_categorical_codes
# 0    male    male                        1
# 1  female  female                        0
# 2  female  female                        0
# 3  female  female                        0
# 4    male    male                        1

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Sex_C   Sex_c   sex_c  \
# 0      0         A/5 21171   7.2500   NaN        S    male    male    male
# 1      0          PC 17599  71.2833   C85        C  female  female  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female  female  female
# 3      0            113803  53.1000  C123        S  female  female  female
# 4      0            373450   8.0500   NaN        S    male    male    male
#
#    Sex_c_categorical_codes  Sex_apply_category
# 0                        1                   0
# 1                        0                   1
# 2                        0                   1
# 3                        0                   1
# 4                        1                   0

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass_new_weird'] = df['Pclass'].apply(lambda x: 'adf' if x == 3 else ('wer' if x == 2 else 'tyu'))

# %%
df[['Pclass', 'Pclass_new_weird']].head(10)
# Out:
#    Pclass Pclass_new_weird
# 0       3              adf
# 1       1              tyu
# 2       3              adf
# 3       1              tyu
# 4       3              adf
# 5       3              adf
# 6       1              tyu
# 7       3              adf
# 8       3              adf
# 9       2              wer

# %%
# Analysis : 
# tyu > adf > wer

# %%
print(df['Pclass'].dtype)
print(df['Pclass_new_weird'].dtype)
# Out:
# int64
# object

# %%
df['Pclass_new_weird_ordered'] = pd.Categorical(
    df['Pclass_new_weird'],
    categories = ['wer','adf','tyu'],  # Custom order (ascending)
    ordered = True 
)

# %%
print(df['Pclass_new_weird_ordered'].dtype)
# Out:
# category

# %%
df['Pclass_new_weird_ordered'].cat.categories
# Out:
# Index(['wer', 'adf', 'tyu'], dtype='object')

# %%
df['Pclass_new_weird_ordered'] > 'wer'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886    False
# 887     True
# 888     True
# 889     True
# 890     True
# Name: Pclass_new_weird_ordered, Length: 891, dtype: bool

# %% [markdown]
# # Date Functionality

# %%
df = pd.DataFrame({
       'event': ['Concert', 'Conference', 'Wedding', 'Reception', 'last_day'],
       'date': ['2025-01-01', '2025-03-15', '2025-07-20', '2025-07-21', '2025-07-31']
})

# %%
df['date_pandas'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#         event        date date_pandas
# 0     Concert  2025-01-01  2025-01-01
# 1  Conference  2025-03-15  2025-03-15
# 2     Wedding  2025-07-20  2025-07-20
# 3   Reception  2025-07-21  2025-07-21
# 4    last_day  2025-07-31  2025-07-31

# %%
print(df.dtypes[['event', 'date', 'date_pandas']])
# Out:
# event                  object
# date                   object
# date_pandas    datetime64[ns]
# dtype: object

# %%
df['date_pandas'].dt.year
# Out:
# 0    2025
# 1    2025
# 2    2025
# 3    2025
# 4    2025
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.month
# Out:
# 0    1
# 1    3
# 2    7
# 3    7
# 4    7
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day
# Out:
# 0     1
# 1    15
# 2    20
# 3    21
# 4    31
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.weekday
# Out:
# 0    2
# 1    5
# 2    6
# 3    0
# 4    3
# Name: date_pandas, dtype: int32

# %%
df['date_pandas'].dt.day_name()
# Out:
# 0    Wednesday
# 1     Saturday
# 2       Sunday
# 3       Monday
# 4     Thursday
# Name: date_pandas, dtype: object

# %%
df['date_pandas'].dt.is_month_end
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: date_pandas, dtype: bool

# %%
df[df['date_pandas'] > '2025-04-02']
# Out:
#        event        date date_pandas
# 2    Wedding  2025-07-20  2025-07-20
# 3  Reception  2025-07-21  2025-07-21
# 4   last_day  2025-07-31  2025-07-31

# %%
df[df['date_pandas'].between('2025-01-01', '2025-06-01')]
# Out:
#         event        date date_pandas
# 0     Concert  2025-01-01  2025-01-01
# 1  Conference  2025-03-15  2025-03-15

# %%
# Date Range 

pd.date_range(start = '2024-01-01', end = '2024-01-10', freq = 'D')
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = '2024-01-01', end = '2024-03-10', freq = 'ME')   # Month End
# Out:
# DatetimeIndex(['2024-01-31', '2024-02-29'], dtype='datetime64[ns]', freq='ME')

# %%
pd.date_range(start = '2024-01-01', end = '2024-03-10', freq = 'MS') # Month Start
# Out:
# DatetimeIndex(['2024-01-01', '2024-02-01', '2024-03-01'], dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# # Date Arithmetic

# %%
df['next_week'] = df['date_pandas'] + pd.Timedelta(days = 7)

# %%
df[['date_pandas', 'next_week']]
# Out:
#   date_pandas  next_week
# 0  2025-01-01 2025-01-08
# 1  2025-03-15 2025-03-22
# 2  2025-07-20 2025-07-27
# 3  2025-07-21 2025-07-28
# 4  2025-07-31 2025-08-07

# %%
df['days_to_event'] = df['date_pandas'] - pd.Timestamp.today()

# %%
df.head()
# Out:
#         event        date date_pandas  next_week              days_to_event
# 0     Concert  2025-01-01  2025-01-01 2025-01-08 -394 days +09:06:47.326069
# 1  Conference  2025-03-15  2025-03-15 2025-03-22 -321 days +09:06:47.326069
# 2     Wedding  2025-07-20  2025-07-20 2025-07-27 -194 days +09:06:47.326069
# 3   Reception  2025-07-21  2025-07-21 2025-07-28 -193 days +09:06:47.326069
# 4    last_day  2025-07-31  2025-07-31 2025-08-07 -183 days +09:06:47.326069

# %%
165/30
# Out:
# 5.5

# %%
# Assignmnet 

# TODO - While creating a task, ask user about the deadline 

# Start Date - Pick automatically from today's date 

# Deadline - 7,10,10

# 1. Task-1| Days left | Green-color
# 2. Task-2| Days left | Red -color        
# 3. Task-3| Days left | Green - color
# 4. Task-4| Days left | Red-color
