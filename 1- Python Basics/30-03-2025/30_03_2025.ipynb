# %%
print(1+1)
print(type(1+1))
# Out:
# 2
# <class 'int'>

# %%
a = 10
b = 20 
print(f"A addition b is {a+b}")
type(a+b)
print(a//b)
type(a//b)
print(a%b)
type(a%b)
print(a**b)
type(a**b)
# Out:
# A addition b is 30
# 0
# 10
# 100000000000000000000
# int

# %%
name = "Pratha  mesh     "
print(name)
# Out:
# Pratha  mesh

# %%
name.strip()
print(name)
# Out:
# Pratha  mesh
